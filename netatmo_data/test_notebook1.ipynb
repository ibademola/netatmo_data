# %%
import requests
import folium
import pandas as pd
import csv
import requests
import time
from datetime import datetime

# %%
import sys
import os

# Add the path to your project
sys.path.append('C:/Users/herde/OneDrive - The Hong Kong Polytechnic University/PhD/PhD Research/Research Objectives/Objective 4/Py_Code/netatmo_data')

# %%
from data_fetcher import fetch_station_ids, fetch_temperature_data

# %%
client_id = "66c2cc07a01c356ed4018397"
client_secret = "HXE1L4R6LyFtxLZPCWcKv1xDyH"
refresh_token = "6639b0eb66bcd29b9809e8f4|ac6b1340af3e5147a4b3cadfc930faf4"
lat_ne = -26.083963
lon_ne = 28.14711
lat_sw = -26.263
lon_sw = 27.92019
csv_file = "JB.csv"

print(client_id, client_secret, refresh_token, lat_ne, lon_ne, lat_sw, lon_sw, csv_file)
jb = fetch_station_ids(client_id, client_secret, refresh_token, lat_ne, lon_ne, lat_sw, lon_sw, csv_file)

# Auckland = fetch_station_ids(client_id,
#                              client_secret,
#                              refresh_token,
#                              lat_ne,
#                              lon_ne,
#                              lat_sw,
#                              lon_sw,
#                              lon_sw
#                              )
# Out:
# 66c2cc07a01c356ed4018397 HXE1L4R6LyFtxLZPCWcKv1xDyH 6639b0eb66bcd29b9809e8f4|ac6b1340af3e5147a4b3cadfc930faf4 -26.083963 28.14711 -26.263 27.92019 JB.csv

# %%
file_path = "JB.csv"
stations_df = pd.read_csv(file_path)

# Assuming your CSV file has columns: 'station_id', 'latitude', 'longitude', 'city'
# Adjust the column names according to your CSV file's structure
# stations_df.columns = ['station_id', 'latitude', 'longitude', 'city']
stations_df.columns = ['MAC_address','module_name','latitude','longitude','altitude','city','full_modules']

# %%
# Step 2.2: Initialize a folium map centered on an average location
center_lat = stations_df['longitude'].mean()
center_lon = stations_df['latitude'].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=10)

# %%
# Step 2.3: Add markers for each station
for _, row in stations_df.iterrows():
    folium.Marker(
        location=[row['longitude'], row['latitude']],
        popup=f"Station ID: {row['MAC_address']}\nCity: {row['city']}",
        icon=folium.Icon(icon="cloud"),
    ).add_to(m)

# Step 2.4: Save the map as an HTML file and display it
m.save('stations_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aac5a9df9923ac745d0f69258023db1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aac5a9df9923ac745d0f69258023db1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aac5a9df9923ac745d0f69258023db1a = L.map(
#                 &quot;map_aac5a9df9923ac745d0f69258023db1a&quot;,
#                 {
#                     center: [-26.132965024218194, 28.057207107448374],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5287a3e9eac82e9f4a492a7b2d19ad29 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5287a3e9eac82e9f4a492a7b2d19ad29.addTo(map_aac5a9df9923ac745d0f69258023db1a);
#
#
#             var marker_181feb3b975dbdcd0aebb74e5b6ac843 = L.marker(
#                 [-26.196435, 28.294562],
#                 {}
#             ).addTo(map_aac5a9df9923ac745d0f69258023db1a);
#
#
#             var icon_623099397db6398fca7231b37abceaaa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_181feb3b975dbdcd0aebb74e5b6ac843.setIcon(icon_623099397db6398fca7231b37abceaaa);
#
#
#         var popup_d6917ee16b837c9b55b61dce1729746b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_512ac038327dfc792ed8489429a5f51e = $(`&lt;div id=&quot;html_512ac038327dfc792ed8489429a5f51e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 70:ee:50:06:8f:36 City: Benoni&lt;/div&gt;`)[0];
#                 popup_d6917ee16b837c9b55b61dce1729746b.setContent(html_512ac038327dfc792ed8489429a5f51e);
#
#
#
#         marker_181feb3b975dbdcd0aebb74e5b6ac843.bindPopup(popup_d6917ee16b837c9b55b61dce1729746b)
#         ;
#
#
#
#
#             var marker_e37d0d9303fb736f7bef101d20425716 = L.marker(
#                 [-26.166744, 28.153814],
#                 {}
#             ).addTo(map_aac5a9df9923ac745d0f69258023db1a);
#
#
#             var icon_23864692aa5e943e3105a3addc131f0e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e37d0d9303fb736f7bef101d20425716.setIcon(icon_23864692aa5e943e3105a3addc131f0e);
#
#
#         var popup_f9fac791db858593950edd725b42024c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d91b5f9906a3829c9643472aebd75e76 = $(`&lt;div id=&quot;html_d91b5f9906a3829c9643472aebd75e76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 70:ee:50:1b:2a:2a City: no city&lt;/div&gt;`)[0];
#                 popup_f9fac791db858593950edd725b42024c.setContent(html_d91b5f9906a3829c9643472aebd75e76);
#
#
#
#         marker_e37d0d9303fb736f7bef101d20425716.bindPopup(popup_f9fac791db858593950edd725b42024c)
#         ;
#
#
#
#
#             var marker_8dd4f71486b8050c8dbc8cf0bfa78b4b = L.marker(
#                 [-26.159239, 28.34119],
#                 {}
#             ).addTo(map_aac5a9df9923ac745d0f69258023db1a);
#
#
#             var icon_5f4a04a831b9067db02e252e33a3ce0d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8dd4f71486b8050c8dbc8cf0bfa78b4b.setIcon(icon_5f4a04a831b9067db02e252e33a3ce0d);
#
#
#         var popup_09f7a48c9e46ff6dcf1927c2c03f2752 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa45f0e756fb34bc37638a2c63453750 = $(`&lt;div id=&quot;html_aa45f0e756fb34bc37638a2c63453750&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 70:ee:50:17:d3:e0 City: no city&lt;/div&gt;`)[0];
#                 popup_09f7a48c9e46ff6dcf1927c2c03f2752.setContent(html_aa45f0e756fb34bc37638a2c63453750);
#
#
#
#         marker_8dd4f71486b8050c8dbc8cf0bfa78b4b.bindPopup(popup_09f7a48c9e46ff6dcf1927c2c03f2752)
#         ;
#
#
#
#
#             var marker_bf940b430af04377b6e914781d1ad2f2 = L.marker(
#                 [-26.1167921, 28.1611809],
#                 {}
#             ).addTo(map_aac5a9df9923ac745d0f69258023db1a);
#
#
#             var icon_d1599a5cb0c8aba97d8f0527d0bbb8b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-ro

# %%
client_id = "66c2cc07a01c356ed4018397"
client_secret = "HXE1L4R6LyFtxLZPCWcKv1xDyH"
refresh_token = "6639b0eb66bcd29b9809e8f4|65f9651b22f2df7fa5471a36edae9ad7"
lat_ne = '-26.083963'
lon_ne = '28.14711'
lat_sw = '-26.263'
lon_sw = '27.92019'
csv_file = "JB.csv"
start_date_stamp = '20150101'
start_time_stamp = '0000'
end_date_stamp = '20201231'
end_time_stamp = '2300'

fetch_temperature_data(client_id, client_secret, refresh_token, csv_file, start_date_stamp, start_time_stamp, end_date_stamp, end_time_stamp)
# Out:
# Error: 400 {"error":"invalid_grant"}
# --------Temperature data for 70:ee:50:06:8f:36, 02:00:00:06:9d:c0 completely downloaded----------
# --------Temperature data for 70:ee:50:1b:2a:2a, 02:00:00:1b:0c:16 completely downloaded----------
# --------Temperature data for 70:ee:50:17:d3:e0, 02:00:00:17:5e:00 completely downloaded----------
# --------Temperature data for 70:ee:50:6b:6c:26, 02:00:00:6b:2f:f6 completely downloaded----------
# --------Temperature data for 70:ee:50:6b:73:18, 02:00:00:6b:35:5e completely downloaded----------
# --------Temperature data for 70:ee:50:64:02:5a, 02:00:00:63:fc:0c completely downloaded----------
# --------Temperature data for 70:ee:50:7f:9e:64, 02:00:00:7f:8d:32 completely downloaded----------
# --------Temperature data for 70:ee:50:83:f3:fc, 02:00:00:83:f5:42 completely downloaded----------
# --------Temperature data for 70:ee:50:05:e1:e6, 02:00:00:12:f7:8e completely downloaded----------
# --------Temperature data for 70:ee:50:65:11:fa, 02:00:00:65:31:0c completely downloaded----------
# --------Temperature data for 70:ee:50:7a:70:f0, 02:00:00:7a:b0:02 completely downloaded----------
# --------Temperature data for 70:ee:50:01:6b:5e, 02:00:00:01:6c:74 completely downloaded----------
# --------Temperature data for 70:ee:50:39:f8:10, 02:00:00:3a:03:a2 completely downloaded----------
# --------Temperature data for 70:ee:50:13:24:5e, 02:00:00:12:f5:c6 completely downloaded----------
# --------Temperature data for 70:ee:50:00:2a:96, 02:00:00:00:2a:e8 completely downloaded----------
# --------Temperature data for 70:ee:50:6b:68:d2, 02:00:00:6b:38:0e completely downloaded----------
# --------Temperature data for 70:ee:50:05:e0:82, 02:00:00:05:3f:c8 completely downloaded----------
# --------Temperature data for 70:ee:50:1e:20:06, 02:00:00:1e:04:78 completely downloaded----------
# --------Temperature data for 70:ee:50:6b:67:e6, 02:00:00:6b:39:a4 completely downloaded----------
# --------Temperature data for 70:ee:50:64:f5:26, 02:00:00:65:25:28 completely downloaded----------
# --------Temperature data for 70:ee:50:74:20:a4, 02:00:00:74:26:58 completely downloaded----------
# --------Temperature data for 70:ee:50:22:e6:74, 02:00:00:22:d5:02 completely downloaded----------
# --------Temperature data for 70:ee:50:37:10:9c, 02:00:00:3a:3b:e8 completely downloaded----------
# --------Temperature data for 70:ee:50:83:e9:74, 02:00:00:84:08:58 completely downloaded----------
# --------Temperature data for 70:ee:50:02:67:9a, 02:00:00:02:67:b0 completely downloaded----------
# --------Temperature data for 70:ee:50:06:ae:be, 02:00:00:05:cd:bc completely downloaded----------
# --------Temperature data for 70:ee:50:13:27:56, 02:00:00:12:f6:d4 completely downloaded----------

# %%
def load_device_and_module_ids_from_csv(csv_file):
    device_module_ids = []
    with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
        reader = csv.reader(file)
        next(reader)  # Skip the header row
        for row in reader:
            device_id = row[0]
            module_id = row[1].strip("[]'")  # Remove square brackets and single quotes
            device_module_ids.append((device_id, module_id))
    return device_module_ids

# %%
device_module_ids = load_device_and_module_ids_from_csv(csv_file)

# %%
device_module_ids
# Out:
# [('70:ee:50:06:8f:36', '02:00:00:06:9d:c0'),
#  ('70:ee:50:1b:2a:2a', '02:00:00:1b:0c:16'),
#  ('70:ee:50:17:d3:e0', '02:00:00:17:5e:00'),
#  ('70:ee:50:6b:6c:26', '02:00:00:6b:2f:f6'),
#  ('70:ee:50:6b:73:18', '02:00:00:6b:35:5e'),
#  ('70:ee:50:64:02:5a', '02:00:00:63:fc:0c'),
#  ('70:ee:50:7f:9e:64', '02:00:00:7f:8d:32'),
#  ('70:ee:50:83:f3:fc', '02:00:00:83:f5:42'),
#  ('70:ee:50:05:e1:e6', '02:00:00:12:f7:8e'),
#  ('70:ee:50:65:11:fa', '02:00:00:65:31:0c'),
#  ('70:ee:50:7a:70:f0', '02:00:00:7a:b0:02'),
#  ('70:ee:50:01:6b:5e', '02:00:00:01:6c:74'),
#  ('70:ee:50:39:f8:10', '02:00:00:3a:03:a2'),
#  ('70:ee:50:13:24:5e', '02:00:00:12:f5:c6'),
#  ('70:ee:50:00:2a:96', '02:00:00:00:2a:e8'),
#  ('70:ee:50:6b:68:d2', '02:00:00:6b:38:0e'),
#  ('70:ee:50:05:e0:82', '02:00:00:05:3f:c8'),
#  ('70:ee:50:1e:20:06', '02:00:00:1e:04:78'),
#  ('70:ee:50:6b:67:e6', '02:00:00:6b:39:a4'),
#  ('70:ee:50:64:f5:26', '02:00:00:65:25:28'),
#  ('70:ee:50:74:20:a4', '02:00:00:74:26:58'),
#  ('70:ee:50:22:e6:74', '02:00:00:22:d5:02'),
#  ('70:ee:50:37:10:9c', '02:00:00:3a:3b:e8'),
#  ('70:ee:50:83:e9:74', '02:00:00:84:08:58'),
#  ('70:ee:50:02:67:9a', '02:00:00:02:67:b0'),
#  ('70:ee:50:06:ae:be', '02:00:00:05:cd:bc'),
#  ('70:ee:50:13:27:56', '02:00:00:12:f6:d4')]

# %%
client_id = "66c2cc07a01c356ed4018397"
client_secret = "HXE1L4R6LyFtxLZPCWcKv1xDyH"
refresh_token = "6639b0eb66bcd29b9809e8f4|981e4675410840cfccb4d3c72bd300b2"

# %%
def convert_to_unix_timestamp(date_string, time_string):
    try:
        # Parse the date and time strings
        date_obj = datetime.strptime(date_string, '%Y%m%d')
        time_obj = datetime.strptime(time_string, '%H%M')
        
        # Combine date and time
        datetime_obj = datetime(date_obj.year, date_obj.month, date_obj.day, time_obj.hour, time_obj.minute)
        
        # Convert to UNIX timestamp
        timestamp = int(datetime_obj.timestamp())
        return timestamp
    except ValueError:
        print("Error: Invalid input format. Please provide date in 'yyyymmdd' and time in 'hhmm' format.")
        return None

# %%
def get_historical_measurements(access_token, device_id, module_id, scale, types, date_begin, date_end, limit=1024):
    url = "https://api.netatmo.net/api/getmeasure"
    
    params = {
        'access_token': access_token,
        'device_id': device_id,
        'module_id': module_id,
        'scale': scale,
        'type': types,
        'date_begin': date_begin,
        'date_end': date_end,
        'limit': limit
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        return None

# %%
def get_historical_measurements_batch(access_token, device_id, module_id, scale, types, date_begin, date_end, limit=1024):
    all_measurements = []

    while date_begin < date_end:
        measurements = get_historical_measurements(access_token, device_id, module_id, scale, types, date_begin, date_end, limit)
        if measurements is None or "body" not in measurements or not measurements["body"]:
            # No more data available or an error occurred, stop the loop
            break

        # Extract the last timestamp from the received data
        last_timestamp = measurements["body"][-1]["beg_time"]
        
        # Append the measurements to the list
        all_measurements.extend(measurements["body"])

        # Update date_begin to fetch the next batch of data
        date_begin = last_timestamp + 86400
        # date_begin = last_timestamp + measurements["body"][-1]["step_time"]

        # Save measurements to CSV file
        save_measurements_to_csv(measurements, device_id, module_id)

        # Introduce a delay to avoid hitting rate limits
        time.sleep(1)

    return all_measurements

# %%
def get_access_token(client_id, client_secret, refresh_token):
    # URL for token endpoint
    token_url = "https://api.netatmo.com/oauth2/token"

    # Parameters for token request
    params = {
        "grant_type": "refresh_token",
        "refresh_token": refresh_token,
        "client_id": client_id,
        "client_secret": client_secret
    }

    # Send POST request to get access token
    response = requests.post(token_url, data=params)

    # Check if request was successful
    if response.status_code == 200:
        # Parse JSON response
        token_data = response.json()
        # Access token
        access_token = token_data["access_token"]
        return access_token
    else:
        print("Error:", response.status_code, response.text)
        return None

# %%
# Get access token
access_token = get_access_token(client_id, client_secret, refresh_token)

# %%
def save_measurements_to_csv(measurements, device_id, module_id):
    # Remove ":" from device and module IDs for filename
    device_id_filename = device_id.replace(":", "")
    module_id_filename = module_id.replace(":", "")
    
    filename = f'{device_id_filename}_{module_id_filename}_measurements.csv'
    
    with open(filename, 'a', newline='') as csvfile:
        fieldnames = ['acquisition_time', 'temperature', 'humidity', 'pressure']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        # Skip writing header if file is not empty
        if csvfile.tell() == 0:
            writer.writeheader()

        acquisition_time = measurements['body'][0]['beg_time']
        step_time = 86400
        # step_time = measurements['body'][0]['step_time']
        for entry in measurements['body']:
            for value in entry['value']:
                row = {
                    'acquisition_time': datetime.utcfromtimestamp(acquisition_time).strftime('%Y%m%d%H%M'),
                    'temperature': value[0],
                    'humidity': value[1],
                    'pressure': value[2]
                }
                writer.writerow(row)
                acquisition_time += step_time

# %%
for device_id, module_id in device_module_ids:
        scale = "1day"  # Change according to your requirement
        types = "Temperature"  # Fetch only temperature data
        date_begin = convert_to_unix_timestamp(start_date_stamp, start_time_stamp)
        date_end = convert_to_unix_timestamp(end_date_stamp, end_time_stamp)
        limit = 1024

        # Fetch historical measurements for the current device ID and module ID pair
        measurements = get_historical_measurements_batch(access_token, device_id, module_id, scale, types, date_begin, date_end, limit)
        print(f'--------Temperature data for {device_id}, {module_id} completely downloaded----------')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 9
#       6 limit = 1024
#       8 # Fetch historical measurements for the current device ID and module ID pair
# ----> 9 measurements = get_historical_measurements_batch(access_token, device_id, module_id, scale, types, date_begin, date_end, limit)
#      10 print(f'--------Temperature data for {device_id}, {module_id} completely downloaded----------')
#
# Cell In[31], line 21, in get_historical_measurements_batch(access_token, device_id, module_id, scale, types, date_begin, date_end, limit)
#      17 date_begin = last_timestamp + 86400
#      18 # date_begin = last_timestamp + measurements["body"][-1]["step_time"]
#      19
#      20 # Save measurements to CSV file
# ---> 21 save_measurements_to_csv(measurements, device_id, module_id)
#      23 # Introduce a delay to avoid hitting rate limits
#      24 time.sleep(1)
#
# Cell In[40], line 24, in save_measurements_to_csv(measurements, device_id, module_id)
#      19 for entry in measurements['body']:
#      20     for value in entry['value']:
#      21         row = {
#      22             'acquisition_time': datetime.utcfromtimestamp(acquisition_time).strftime('%Y%m%d%H%M'),
#      23             'temperature': value[0],
# ---> 24             'humidity': value[1],
#      25             'pressure': value[2]
#      26         }
#      27         writer.writerow(row)
#      28         acquisition_time += step_time
#
# IndexError: list index out of range
